# %%
df = pd.read_csv("./inputs/shoppersentiments/TeePublic_review.csv", encoding="latin-1")

# %%
df
# Out:
#         reviewer_id store_location   latitude   longitude  date  month  \
# 0               0.0             US  37.090240  -95.712891  2023      6
# 1               1.0             US  37.090240  -95.712891  2023      6
# 2               2.0             US  37.090240  -95.712891  2023      6
# 3               3.0             US  37.090240  -95.712891  2023      6
# 4               4.0             CA  56.130366 -106.346771  2023      6
# ...             ...            ...        ...         ...   ...    ...
# 278095     278095.0             US  37.090240  -95.712891  2018      4
# 278096     278096.0             HR  45.100000   15.200000  2018      4
# 278097     278097.0             US  37.090240  -95.712891  2018      4
# 278098     278098.0             US  37.090240  -95.712891  2018      4
# 278099          NaN             US  37.090240  -95.712891  2018      4
#
#                  year                                            title  \
# ...

# %%
ratings_distribution = px.histogram( df, x='review-label', title='Distribution of Ratings')
ratings_distribution.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 ratings_distribution = px.histogram( df, x='review-label', title='Distribution of Ratings')
# ----> 2 ratings_distribution.show()
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
# ...
